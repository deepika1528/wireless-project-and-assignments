# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# NS-3 Simulation Execution\n",
    "\n",
    "Project: Adaptive Cross Layer Control for Scalable Wireless Ad Hoc Networks\n",
    "Name: Mani Deepika Arja\n",
    "Reg No: 23MIC7296\n",
    "\n",
    "This notebook demonstrates how the NS-3 simulation is executed."
   ]
  },

  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Navigate to ns-3 directory\n",
    "!cd ~/ns-3-dev"
   ]
  },

  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Build NS-3\n",
    "!cd ~/ns-3-dev && ./ns3 build"
   ]
  },

  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Run Simulation (Basic)\n",
    "!cd ~/ns-3-dev && ./ns3 run \"scratch/final-simulation\""
   ]
  },

  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Run Simulation with Inputs\n",
    "!cd ~/ns-3-dev && ./ns3 run \"scratch/final-simulation --nodes=75 --packets=100\""
   ]
  },

  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Sample Output\n",
    "\n",
    "========== SIMULATION RESULT ==========\n",
    "Number of Nodes: 75\n",
    "Packets Sent: 136\n",
    "Packets Received: 45\n",
    "Packet Delivery Ratio (PDR): 33.0882%\n",
    "End-to-End Delay: 0.251682 sec\n",
    "Average Jitter: 0.0973333 sec\n",
    "Throughput: 0.427733 Kbps\n",
    "Communication Overhead: 112\n",
    "Computational Overhead: 0\n",
    "Energy Consumption: 0.6416 J"
   ]
  },

  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Multiple runs for analysis\n",
    "!cd ~/ns-3-dev && ./ns3 run \"scratch/final-simulation --nodes=75 --packets=100\"\n",
    "!cd ~/ns-3-dev && ./ns3 run \"scratch/final-simulation --nodes=85 --packets=110\"\n",
    "!cd ~/ns-3-dev && ./ns3 run \"scratch/final-simulation --nodes=100 --packets=150\"\n",
    "!cd ~/ns-3-dev && ./ns3 run \"scratch/final-simulation --nodes=150 --packets=120\"\n",
    "!cd ~/ns-3-dev && ./ns3 run \"scratch/final-simulation --nodes=200 --packets=180\""
   ]
  },

  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## NetAnim Visualization\n",
    "\n",
    "Steps:\n",
    "1. Generate XML file from ns-3 simulation.\n",
    "2. Open NetAnim tool.\n",
    "3. Load the XML file.\n",
    "\n",
    "Command used:\n",
    "`./NetAnim output.xml`\n",
    "\n",
    "The animation shows node communication and packet flow."
   ]
  }
 ],
 "metadata": {},
 "nbformat": 4,
 "nbformat_minor": 2
}
